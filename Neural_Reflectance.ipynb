# %% [markdown]
# <a href="https://colab.research.google.com/github/AnasMuhammad123/Covid-19-Face-Mask-Detection/blob/main/Neural_Reflectance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install OpenEXR
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for OpenEXR: filename=OpenEXR-1.3.9-cp39-cp39-linux_x86_64.whl size=244306 sha256=39b7a37d9c8a1f74d3f271bf87a53fb9ceff6a2b8bdf48455ba4926fa6fb562d
#   Stored in directory: /root/.cache/pip/wheels/32/73/e9/abb6c0a17d469a0640a2b85dce0a6360a7dd5d86e35c36b9fa
# Successfully built OpenEXR
# ...

# %% [markdown]
# Cloning github

# %%
# !git clone https://github.com/junxuan-li/Neural-Reflectance-PS.git
# Out:
# Cloning into 'Neural-Reflectance-PS'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 61 (delta 17), reused 52 (delta 14), pack-reused 0
# Unpacking objects: 100% (61/61), 35.13 MiB | 12.59 MiB/s, done.

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %mkdir /content/Neural-Reflectance-PS/data

# %%
# %cp /gdrive/MyDrive/DiLiGenT.zip /content

# %%
# !unzip /content/DiLiGenT.zip -d /content/Neural-Reflectance-PS/data
# Out:
# Archive:  /content/DiLiGenT.zip
#    creating: /content/Neural-Reflectance-PS/data/DiLiGenT/
#    creating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_ACCV10Wu.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_CVPR08Alldrin.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_CVPR10Higo.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_CVPR12Ikehata.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_CVPR12Shi.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_CVPR14Ikehata.mat
#   inflating: /content/Neural-Reflectance-PS/data/DiLiGenT/estNormalNonLambert/ballPNG_Normal_ECCV12Shi.mat
# ...

# %%
# %cd /content/Neural-Reflectance-PS
# Out:
# /content/Neural-Reflectance-PS

# %%
# !bash configs/download_precomputed_models.sh
# Out:
# downloading precomputed models
# Start downloading ...
# --2023-04-12 23:47:16--  https://www.dropbox.com/s/74nbauzt1h8rkb3/diligent_precomputed.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/74nbauzt1h8rkb3/diligent_precomputed.zip [following]
# --2023-04-12 23:47:16--  https://www.dropbox.com/s/raw/74nbauzt1h8rkb3/diligent_precomputed.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc37dba4a678a0f074b19b93cd42.dl.dropboxusercontent.com/cd/0/inline/B6HbFdCoLDj162C2UqcTfrWHclzzBcfe3AtLLOreE9yNjD4g1ZF3r19UklaTxYS7ZNdUvoBrsiOLm3sr9sp0RzNhovuZz2-Cp-CCpuJNTXOsJKRR_F06w4OLbaDV50WUZaJ0348_EhQtvSUzkZZEK9E9RnRUjYHKV6fg5zM7mGV-ww/file# [following]
# ...

# %%
# !bash configs/test_precomputed_models.sh
# Out:
# Start unzipping ...
# Archive:  diligent_precomputed.zip
#    creating: diligent/
#    creating: diligent/ball/
#    creating: diligent/ball/depth/
#    creating: diligent/ball/depth/cast_shading/
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_002.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_003.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_004.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_005.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_006.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_007.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_008.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_009.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_010.png
#   inflating: diligent/ball/depth/cast_shading/est_cast_shading_011.png
# ...

# %%
# !python train.py --config /content/Neural-Reflectance-PS/configs/diligent/reading.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 190,  iter:  6/ 12, Training: 0.0125, Val: 12.9858  cost_time: 2 m 37 s,  est_time: 5 m 41 s
# epoch: 190,  iter:  7/ 12, Training: 0.0130, Val: 12.9884  cost_time: 2 m 37 s,  est_time: 5 m 41 s
# epoch: 190,  iter:  8/ 12, Training: 0.0126, Val: 12.8087  cost_time: 2 m 37 s,  est_time: 5 m 41 s
# epoch: 190,  iter:  9/ 12, Training: 0.0121, Val: 12.7297  cost_time: 2 m 37 s,  est_time: 5 m 41 s
# epoch: 190,  iter: 10/ 12, Training: 0.0120, Val: 12.8188  cost_time: 2 m 37 s,  est_time: 5 m 41 s
# epoch: 190,  iter: 11/ 12, Training: 0.0134, Val: 13.0316  cost_time: 2 m 38 s,  est_time: 5 m 41 s
# epoch: 190,  iter: 12/ 12, Training: 0.0121, Val: 13.2295  cost_time: 2 m 38 s,  est_time: 5 m 41 s
# epoch: 191,  iter:  1/ 12, Training: 0.0134, Val: 13.3609  cost_time: 2 m 38 s,  est_time: 5 m 41 s
# epoch: 191,  iter:  2/ 12, Training: 0.0125, Val: 13.4692  cost_time: 2 m 38 s,  est_time: 5 m 41 s
# ...

# %%
# !python train.py --config /content/Neural-Reflectance-PS/configs/diligent/cat.yml --testing "True" --quick_testing "True"
# Out:
# 2023-04-13 00:01:37.029858: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 00:01:37.977251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found checkpoints ./runs/paper_config/diligent/ball/model_params_00600.pth
# ================ evaluation results===============
# Testing RGB L1: 0.5013     Normal MAE: 2.4332
# ...

# %% [markdown]
# # New Section

# %%
# !python train.py --config configs/diligent/reading.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 190,  iter:  6/ 12, Training: 0.0095, Val: 10.9628  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter:  7/ 12, Training: 0.0097, Val: 10.8856  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter:  8/ 12, Training: 0.0095, Val: 10.9273  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter:  9/ 12, Training: 0.0095, Val: 10.9578  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter: 10/ 12, Training: 0.0099, Val: 10.9647  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter: 11/ 12, Training: 0.0100, Val: 10.9242  cost_time: 2 m 40 s,  est_time: 5 m 47 s
# epoch: 190,  iter: 12/ 12, Training: 0.0098, Val: 10.9949  cost_time: 2 m 40 s,  est_time: 5 m 46 s
# epoch: 191,  iter:  1/ 12, Training: 0.0096, Val: 11.0748  cost_time: 2 m 40 s,  est_time: 5 m 46 s
# epoch: 191,  iter:  2/ 12, Training: 0.0095, Val: 11.1820  cost_time: 2 m 40 s,  est_time: 5 m 46 s
# ...
